# %% [markdown]
# #Importar archivos y librerías

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/trainPrepocesado.csv')
y_train = train['RENDIMIENTO_GLOBAL']
x_train = train.drop(columns=['RENDIMIENTO_GLOBAL'])
train.head()
# Out:
#    ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0             0.074380                    0.00
# 1             0.024793                    0.25
# 2             0.115702                    0.00
# 3             0.008264                    0.00
# 4             0.041322                    0.00
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                        0.857143                     0.25
# 1                        0.571429                     0.00
# 2                        0.571429                     1.00
# 3                        0.714286                     0.00
# 4                        0.571429                     0.75
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0              0.500000                 1.0             0.555556
# 1              0.500000                 0.0             0.666667
# 2              0.500000                 1.0             0.444444
# 3              0.666667                 1.0             0.000000
# 4              0.500000                 1.0             0.222222
#
#    FAMI_EDUCACIONMADRE  ESTU_PAGOMATRICULAPROPIO  RENDIMIENTO_GLOBAL
# 0             1.000000                       0.0            1.000000
# 1             0.555556                       0.0            0.333333
# 2             0.444444                       0.0            0.333333
# 3             0.444444                       0.0            0.000000
# 4             0.222222                       0.0            0.666667

# %%
y_train.head()
# Out:
# 0    1.000000
# 1    0.333333
# 2    0.333333
# 3    0.000000
# 4    0.666667
# Name: RENDIMIENTO_GLOBAL, dtype: float64

# %%
x_test = pd.read_csv('/content/testPrepocesado.csv')
x_test.drop(columns=['Unnamed: 0'], inplace=True)
x_test.head()
# Out:
#    ESTU_PRGM_ACADEMICO  ESTU_PRGM_DEPARTAMENTO  \
# 0             0.066116                    0.25
# 1             0.008264                    0.00
# 2             0.000000                    0.00
# 3             0.033058                    0.25
# 4             0.008264                    0.25
#
#    ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_HORASSEMANATRABAJA  \
# 0                        0.142857                     0.25
# 1                        0.571429                     0.75
# 2                        0.428571                     0.00
# 3                        0.428571                     0.75
# 4                        0.571429                     0.50
#
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_EDUCACIONPADRE  \
# 0              0.500000                 1.0             0.666667
# 1              0.333333                 1.0             0.444444
# 2              0.500000                 1.0             0.333333
# 3              0.166667                 0.0             0.111111
# 4              0.333333                 1.0             0.444444
#
#    FAMI_EDUCACIONMADRE  ESTU_PAGOMATRICULAPROPIO
# 0             0.222222                       1.0
# 1             0.666667                       0.0
# 2             0.444444                       0.0
# 3             0.111111                       0.0
# 4             0.444444                       0.0

# %%
y_test = pd.read_csv('/content/submission_examplePrepocesado.csv')
y_test.drop(columns=['ID'], inplace=True)
y_test.head()
# Out:
#    RENDIMIENTO_GLOBAL
# 0            0.666667
# 1            0.666667
# 2            0.000000
# 3            0.333333
# 4            0.666667

# %% [markdown]
# #Sobremuestreo y modelo LinearSVC

# %% [markdown]
# Se importa las librerías responsable del modelo y desde el modelo hasta los preprocesamiento de los datos antes de incluirlos dentro del modelo.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, accuracy_score
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA

# %% [markdown]
# Se usa los metoso de sobremuestreo para emparejar equilibrar las clases con el fin de obtener un mayor conjunto de datos y equilibrados, y por otro lado, la funcion PCA encargada de eliminar componentes que se consideran innecesarias con respecto a un limite impuesto por el usuario.

# %%
y_train = y_train.astype(str)
y_test = y_test.astype(str)
smote = SMOTE(random_state=42)
x_train_resampled, y_train_resampled = smote.fit_resample(x_train, y_train)
pca = PCA(n_components=0.9, random_state=42)
x_train_resampled = pca.fit_transform(x_train_resampled)
x_test_ = pca.transform(x_test)

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(random_state=42)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
y_validation = y_validation.astype(str)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 0.24933454631220728
# Classification Report:
#                     precision    recall  f1-score   support
#
#                0.0       0.25      0.35      0.29      7483
# 0.3333333333333333       0.24      0.22      0.23      7421
# 0.6666666666666666       0.25      0.25      0.25      7532
#                1.0       0.25      0.18      0.21      7243
#
#           accuracy                           0.25     29679
#          macro avg       0.25      0.25      0.25     29679
#       weighted avg       0.25      0.25      0.25     29679

# %% [markdown]
# Con esta funcion buscamos la predicion corresponda a un las ingresadas por el creador de la competencia y legibles para el kaggle.

# %%
y_pred_df = pd.DataFrame(y_pred, columns=['RENDIMIENTO_GLOBAL'])
mapa = {
    '0.0': 'bajo',
    '0.3333333333333333': 'medio-bajo',
    '0.6666666666666666': 'medio-alto',
    '1.0': 'alto'
}
y_pred_df['RENDIMIENTO_GLOBAL'] = y_pred_df['RENDIMIENTO_GLOBAL'].map(mapa)
y_pred_df =  pd.concat([pd.read_csv('/content/submission_examplePrepocesado.csv')['ID'], y_pred_df], axis=1)
y_pred_df.to_csv('sln.csv', index=False)
